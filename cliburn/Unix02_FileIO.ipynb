# %% [markdown]
# # File I/O

# %% [markdown]
# ## Creating a file

# %% [markdown]
# ### Using an editor

# %% [markdown]
# ### Using redirection

# %%
ls
# Out:
# Unix01_File_And_Directory.ipynb		Unix03_File_And_Text_Manipulation.ipynb
# Unix02_FileIO.ipynb			Unix04_Varaibles.ipynb

# %%
echo "Hello Unix"
# Out:
# Hello Unix

# %%
echo "Hello Unix" > foo.txt

# %% [markdown]
# ### Using `heredocs`

# %%
cat > bar.txt << EOF
This old man he played one
He played knick knack on my thumb
EOF

# %% [markdown]
# ## View file contents

# %%
cat foo.txt
# Out:
# Hello Unix

# %%
cat bar.txt
# Out:
# This old man he played one
# He played knick knack on my thumb

# %% [markdown]
# ## More redirection

# %%
echo "I love bash" >> foo.txt

# %%
cat >> bar.txt << EOF
This old man he played two
He played knick knack on my shoe
EOF

# %% [markdown]
# ## View file contents

# %%
cat foo.txt
# Out:
# Hello Unix
# I love bash

# %%
cat bar.txt
# Out:
# This old man he played one
# He played knick knack on my thumb
# This old man he played two
# He played knick knack on my shoe

# %% [markdown]
# ## More redirection

# %%
echo "Many people hate bash" > foo.txt

# %% [markdown]
# Oops, you've over-written the original contents of foo.txt and they are lost forever.

# %%
cat foo.txt
# Out:
# Many people hate bash

# %% [markdown]
# ### Safety
#
# If you file contents are precious and should not be changed (e..g raw data), you can change permisions to read-only.

# %%
ls -l foo.txt
# Out:
# -rw-r--r--  1 cliburn  staff  22 May 21 10:50 foo.txt

# %%
chmod -w foo.txt

# %%
ls -l foo.txt
# Out:
# -r--r--r--  1 cliburn  staff  22 May 21 10:50 foo.txt

# %%
echo "Try to overwrite" > foo.txt
# Out:
# bash: foo.txt: Permission denied
# : 1

# %% [markdown]
# ## Redirecting command output

# %%
ls
# Out:
# Unix01_File_And_Directory.ipynb		Unix04_Varaibles.ipynb
# Unix02_FileIO.ipynb			bar.txt
# Unix03_File_And_Text_Manipulation.ipynb	foo.txt

# %%
ls > contents.txt

# %%
cat contents.txt
# Out:
# Unix01_File_And_Directory.ipynb
# Unix02_FileIO.ipynb
# Unix03_File_And_Text_Manipulation.ipynb
# Unix04_Varaibles.ipynb
# contents.txt

# %% [markdown]
# ### Redirecting error messages

# %%
cat foobar.txt
# Out:
# cat: foobar.txt: No such file or directory
# : 1

# %%
cat foobar.txt > error.txt
# Out:
# cat: foobar.txt: No such file or directory
# : 1

# %%
ls e*txt
# Out:
# error.txt

# %%
cat error.txt

# %% [markdown]
# ### Why is error.txt it empty?

# %% [markdown]
# The standard `>` is  short for `1>` which means re-direct the standard output stream.

# %%
cat foobar.txt 1> stdout.txt
# Out:
# cat: foobar.txt: No such file or directory
# : 1

# %%
cat stdout.txt

# %% [markdown]
# To redirect the standard error stream, you need `2>``.

# %%
cat foobar.txt 2> stderr.txt
# Out:
# : 1

# %%
cat stderr.txt
# Out:
# cat: foobar.txt: No such file or directory

# %% [markdown]
# You can redirect to both.

# %%
cat foobar.txt > results.txt 2> errors.txt
# Out:
# : 1

# %%
cat results.txt

# %%
cat errors.txt
# Out:
# cat: foobar.txt: No such file or directory

# %% [markdown]
# You can also redirect both streams to the same file with `&>`.

# %%
cat foobar.txt &> combined.txt
# Out:
# : 1

# %%
cat combined.txt
# Out:
# cat: foobar.txt: No such file or directory

# %% [markdown]
# ### Simple text operations

# %%
cat contents.txt
# Out:
# Unix01_File_And_Directory.ipynb
# Unix02_FileIO.ipynb
# Unix03_File_And_Text_Manipulation.ipynb
# Unix04_Varaibles.ipynb
# bar.txt
# contents.txt
# foo.txt

# %%
head -3 contents.txt
# Out:
# Unix01_File_And_Directory.ipynb
# Unix02_FileIO.ipynb
# Unix03_File_And_Text_Manipulation.ipynb

# %%
tail -3 contents.txt
# Out:
# bar.txt
# contents.txt
# foo.txt

# %%
wc contents.txt
# Out:
#        7       7     144 contents.txt

# %%
wc -l contents.txt
# Out:
#        7 contents.txt

# %%
wc -w contents.txt
# Out:
#        7 contents.txt

# %%
wc -c contents.txt
# Out:
#      144 contents.txt

# %% [markdown]
# If you don't want the filename, force it to read from standard input.

# %%
wc -c < contents.txt
# Out:
#      128

# %% [markdown]
# ### Piping

# %%
head -3 contents.txt | wc -c
# Out:
#       92

# %%
head -3 contents.txt | wc -c > word_count.txt

# %%
cat word_count.txt
# Out:
#       92

# %% [markdown]
# ### Clean up

# %%
ls
# Out:
# Unix01_File_And_Directory.ipynb		error.txt
# Unix02_FileIO.ipynb			errors.txt
# Unix03_File_And_Text_Manipulation.ipynb	foo.txt
# Unix04_Varaibles.ipynb			results.txt
# bar.txt					stderr.txt
# combined.txt				stdout.txt
# contents.txt				word_count.txt

# %% [markdown]
# ### Fancy globbing

# %%
shopt -s extglob

# %% [markdown]
# Specifying what NOT to list.

# %%
ls !(*.ipynb)
# Out:
# bar.txt		contents.txt	errors.txt	results.txt	stdout.txt
# combined.txt	error.txt	foo.txt		stderr.txt	word_count.txt

# %%
ls !(*.txt)
# Out:
# Unix01_File_And_Directory.ipynb		Unix03_File_And_Text_Manipulation.ipynb
# Unix02_FileIO.ipynb			Unix04_Varaibles.ipynb

# %% [markdown]
# Specifying alternatives.

# %%
ls *{.txt,.ipynb}
# Out:
# Unix01_File_And_Directory.ipynb		error.txt
# Unix02_FileIO.ipynb			errors.txt
# Unix03_File_And_Text_Manipulation.ipynb	foo.txt
# Unix04_Varaibles.ipynb			results.txt
# bar.txt					stderr.txt
# combined.txt				stdout.txt
# contents.txt				word_count.txt

# %% [markdown]
# ### Clean up

# %%
rm -f !(*.ipynb)

# %%
ls
# Out:
# Unix01_File_And_Directory.ipynb		Unix03_File_And_Text_Manipulation.ipynb
# Unix02_FileIO.ipynb			Unix04_Varaibles.ipynb

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1. Create 3 files with the same contents (say `lsd1.txt`, `lsd2.txt`, `lsd3.txt`)
#
# ```
# Two of the most famous products of Berkeley are LSD and Unix.
# I don’t think that this is a coincidence.
# ```
#
# using
#
# - A text editor
# - Echo
# - A HereDoc

# %% [markdown]
# 2. Count the number of words in the second sentence only of lsd1.txt
